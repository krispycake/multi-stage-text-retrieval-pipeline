# %%
# !pip install transformers datasets torch torchvision torchtext
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.44.2)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: torchtext in /opt/conda/lib/python3.10/site-packages (0.18.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel, AutoModelForSequenceClassification
from datasets import load_dataset
import random
import logging

# Set random seed for reproducibility
random.seed(42)

# %%
# Load datasets
max_samples = 10000  # Limit the number of samples for each dataset

hotpotqa_data = load_dataset("BeIR/hotpotqa-generated-queries", split="train").select(range(max_samples))
nq_data = load_dataset("BeIR/nq-generated-queries", split="train").select(range(max_samples))
fiqa_data = load_dataset("BeIR/fiqa-generated-queries", split="train").select(range(max_samples))

# Check the loaded datasets
print(hotpotqa_data)
print(nq_data)
print(fiqa_data)
# Out:
# Dataset({
#     features: ['_id', 'title', 'text', 'query'],
#     num_rows: 10000
# })
# Dataset({
#     features: ['_id', 'title', 'text', 'query'],
#     num_rows: 10000
# })
# Dataset({
#     features: ['_id', 'title', 'text', 'query'],
#     num_rows: 10000
# })

# %%
# Check the loaded datasets
print(hotpotqa_data)
print(nq_data)
print(fiqa_data)
# Out:
# Dataset({
#     features: ['_id', 'title', 'text', 'query'],
#     num_rows: 10000
# })
# Dataset({
#     features: ['_id', 'title', 'text', 'query'],
#     num_rows: 10000
# })
# Dataset({
#     features: ['_id', 'title', 'text', 'query'],
#     num_rows: 10000
# })

# %%
# Function to preprocess data
def preprocess_data(data):
    passages = []
    queries = []
    for entry in data:
        if 'text' in entry:
            passages.append(entry['text'])
        if 'query' in entry:
            queries.append(entry['query'])
    return passages, queries

# Process each dataset
hotpotqa_passages, hotpotqa_queries = preprocess_data(hotpotqa_data)
nq_passages, nq_queries = preprocess_data(nq_data)
fiqa_passages, fiqa_queries = preprocess_data(fiqa_data)

# Combine passages and queries
passages = hotpotqa_passages + nq_passages + fiqa_passages
queries = hotpotqa_queries + nq_queries + fiqa_queries

# %%
# Process each dataset
hotpotqa_passages, hotpotqa_queries = preprocess_data(hotpotqa_data)
nq_passages, nq_queries = preprocess_data(nq_data)
fiqa_passages, fiqa_queries = preprocess_data(fiqa_data)

# Combine passages and queries
passages = hotpotqa_passages + nq_passages + fiqa_passages
queries = hotpotqa_queries + nq_queries + fiqa_queries

# %%
# Example of accessing the processed data
print(hotpotqa_queries[:5])   # Print first 5 queries from HotpotQA
print(hotpotqa_passages[:5])  # Print first 5 passages from HotpotQA
# Out:
# ['anarchism defined', 'what age do children with autism develop', 'what is albedo', 'what is the word for the first letter in latin', 'where is alabama']
# ['Anarchism is a political philosophy that advocates self-governed societies based on voluntary institutions. These are often described as stateless societies, although several authors have defined them more specifically as institutions based on non-hierarchical free associations. Anarchism holds the state to be undesirable, unnecessary and harmful.', "Autism is a neurodevelopmental disorder characterized by impaired social interaction, impaired verbal and non-verbal communication, and restricted and repetitive behavior. Parents usually notice signs in the first two years of their child's life. These signs often develop gradually, though some children with autism reach their developmental milestones at a normal pace and then regress. The diagnostic criteria require that symptoms become apparent in early childhood, typically before age three.", 'Albedo ( ) is a measure for reflectance or optical brightness (Latin "albedo," "whiteness") of a surface. It is dimensionless and measured on a scale from zero (corresponding to a black body that absorbs all incident radiation) to one (corresponding to a white body that reflects all incident radiation).', 'A (named , plural "As", "A\'s", "a"s, "a\'s" or "aes" ) is the first letter and the first vowel of the ISO basic Latin alphabet. It is similar to the Ancient Greek letter alpha, from which it derives. The upper-case version consists of the two slanting sides of a triangle, crossed in the middle by a horizontal bar. The lower-case version can be written in two forms: the double-storey a and single-storey ɑ. The latter is commonly used in handwriting and fonts based on it, especially fonts intended to be read by children, and is also found in italic type.', 'Alabama ( ) is a state in the southeastern region of the United States. It is bordered by Tennessee to the north, Georgia to the east, Florida and the Gulf of Mexico to the south, and Mississippi to the west. Alabama is the 30th largest by area and the 24th-most populous of the U.S. states. With a total of 1500 mi of inland waterways, Alabama has among the most of any state.']

# %%
# Load small embedding model
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")

# Set device to GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 384, padding_idx=0)
#     (position_embeddings): Embedding(512, 384)
#     (token_type_embeddings): Embedding(2, 384)
#     (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-5): 6 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=384, out_features=384, bias=True)
#             (key): Linear(in_features=384, out_features=384, bias=True)
#             (value): Linear(in_features=384, out_features=384, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=384, out_features=384, bias=True)
#             (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=384, out_features=1536, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=1536, out_features=384, bias=True)
#           (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=384, out_features=384, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
# Function to get embeddings for passages
def get_embeddings(passages, batch_size=64):
    embeddings = []
    for i in range(0, len(passages), batch_size):
        batch_passages = passages[i:i + batch_size]
        inputs = tokenizer(batch_passages, return_tensors='pt', truncation=True, padding=True, max_length=128)
        inputs = {k: v.to(device) for k, v in inputs.items()}  # Move input tensors to GPU
        with torch.no_grad():
            embedding = model(**inputs).last_hidden_state.mean(dim=1).cpu()  # Move back to CPU after processing
        embeddings.append(embedding)
    return torch.cat(embeddings)

passage_embeddings = get_embeddings(passages)
print(passage_embeddings.shape)
# Out:
# torch.Size([30000, 384])

# %%
num_passages = len(passages)
num_embeddings = passage_embeddings.shape[0]

# Check if they match
if num_passages == num_embeddings:
    print(f"The number of passages ({num_passages}) matches the number of embeddings ({num_embeddings}).")
else:
    print(f"Mismatch: Number of passages is {num_passages}, but number of embeddings is {num_embeddings}.")
# Out:
# The number of passages (30000) matches the number of embeddings (30000).

# %%
# Load the cross-encoder model for reranking
rank_model = AutoModelForSequenceClassification.from_pretrained("cross-encoder/ms-marco-MiniLM-L-12-v2")
rank_tokenizer = AutoTokenizer.from_pretrained("cross-encoder/ms-marco-MiniLM-L-12-v2")

# Move the model to the appropriate device
rank_model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 384, padding_idx=0)
#       (position_embeddings): Embedding(512, 384)
#       (token_type_embeddings): Embedding(2, 384)
#       (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=384, out_features=384, bias=True)
#               (key): Linear(in_features=384, out_features=384, bias=True)
#               (value): Linear(in_features=384, out_features=384, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=384, out_features=384, bias=True)
#               (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=384, out_features=1536, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=1536, out_features=384, bias=True)
#             (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=384, out_features=384, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=384, out_features=1, bias=True)
# )

# %%
# Function to rerank passages based on a query
def rerank_passages(query, passages, passage_embeddings):
    query_embedding = get_embeddings([query])  # Get embedding for the query
    scores = []
    
    for passage_embedding in passage_embeddings:
        score = torch.nn.functional.cosine_similarity(query_embedding, passage_embedding.unsqueeze(0))  # Ensure correct dimension
        scores.append(score.item())
        
    ranked_indices = np.argsort(scores)[::-1]  # Sort by descending scores
    return ranked_indices

# %%
# Function to rerank passages based on the question
def rerank_passages(question, passages_batch):
    # Prepare the input for the cross-encoder
    inputs = rank_tokenizer([[question, passage] for passage in passages_batch], return_tensors='pt', padding=True, truncation=True)
    inputs = {k: v.to(device) for k, v in inputs.items()}  # Move input tensors to TPU

    # Get the model's predictions (scores)
    with torch.no_grad():
        scores = rank_model(**inputs).logits  # Get raw scores from the model

    # Check the shape of scores and process accordingly
    if scores.shape[1] == 1:  # If model returns a single score
        scores = scores.squeeze()  # Remove the extra dimension
        ranked_indices = torch.argsort(scores, descending=True).cpu().numpy()
    else:  # If model returns two scores for binary classification
        scores = scores.softmax(dim=1)[:, 1]  # Get the positive class probabilities
        ranked_indices = torch.argsort(scores, descending=True).cpu().numpy()

    return ranked_indices

# %%
# Process and rerank passages
for i in range(0, len(passages), 64):  # Using batch size of 64
    batch_passages = passages[i:i + 64]  # Select the current batch of 64
    
    # Rerank this batch
    ranked_batch_indices = rerank_passages("what age do children with autism develop?", batch_passages)
    
    # Get the ranked passages for this batch
    ranked_batch_passages = [batch_passages[idx] for idx in ranked_batch_indices]
    
    # Print a limited number of ranked passages
    print("Ranked passages for batch:")
    for passage in ranked_batch_passages[:1]:  # Print 1 ranked passage
        print(passage[:50])  # Print only the first 50 characters of each passage
        print("...")  # Indicate that the passage is longer
# Out:
# Ranked passages for batch:
# Autism is a neurodevelopmental disorder characteri
# ...
# Ranked passages for batch:
# Alexander III of Macedon (20/21 July 356 BC – 10/1
# ...
# Ranked passages for batch:
# Ataxia is a neurological sign consisting of lack o
# ...
# Ranked passages for batch:
# April 15 is the day of the year in the Gregorian c
# ...
# Ranked passages for batch:
# August 13 is the day of the year in the Gregorian
# ...
# Ranked passages for batch:
# The Americans with Disabilities Act of 1990 ( /121
# ...
# Ranked passages for batch:
# August 18 is the day of the year in the Gregorian
# ...
# Ranked passages for batch:
# Alexander III married at the age of 9 "Alaxandair
# ...
# Ranked passages for batch:
# The age of consent is the age at which a person is
# ...
# Ranked passages for batch:
# Hermann Kolbe ("Adolph Wilhelm Hermann Kolbe", 27
# ...
# Ranked passages for batch:
# April 14 is the day of the year in the Gregorian c
# ...
# Ranked passages for batch:
# Anne Brontë ( , "commonly" ; 17 January 1820 – 28
# ...
# Ranked passages for batch:
# Aaliyah Dana Haughton ( ; January 16, 1979 – Augus
# ...
# Ranked passages for batch:
# April 27 is the day of the year in the Gregorian c
# ...
# Ranked passages for batch:
# Apoptosis (from Ancient Greek ἀπόπτωσις "falling o
# ...
# Ranked passages for batch:
# April 21 is the day of the year in the Gregorian c
# ...
# Ranked passages for batch:
# Adam Carolla (born May 27, 1964) is an American co
# ...
# Ranked passages for batch:
# Andrei Dmitrievich Sakharov (Russian: Андре́й Дми́
# ...
# Ranked passages for batch:
# Albinism in humans is a congenital disorder charac
# ...
# Ranked passages for batch:
# Alexey Leonidovich Pajitnov (Russian: Алексе́й Лео
# ...
# Ranked passages for batch:
# Alphonse Gabriel Capone ( ; ] ; January 17, 1899 –
# ...
# Ranked passages for batch:
# Britney Jean Spears (born December 2, 1981) is an
# ...
# Ranked passages for batch:
# Standard gauge: 1032 km (2006)
# ...
# Ranked passages for batch:
# Bjarne Stroustrup ( ; ] ; born 30 December 1950) i
# ...
# Ranked passages for batch:
# Brain abscess (or cerebral abscess) is an abscess
# ...
# Ranked passages for batch:
# Blaise Pascal ( ; ] ; 19 June 1623 – 19 August 166
# ...
# Ranked passages for batch:
# Brion Gysin (19 January 1916 – 13 July 1986) was a
# ...
# Ranked passages for batch:
# BBC Radio 1 is a British radio station operated by
# ...
# Ranked passages for batch:
# Barry Lamar Bonds (born July 24, 1964) is an Ameri
# ...
# Ranked passages for batch:
# William Robert "Billy Bob" Thornton (born August 4
# ...
# Ranked passages for batch:
# A boy band (or boyband) is loosely defined as a vo
# ...
# Ranked passages for batch:
# Behavior (American English) or behaviour (Commonwe
# ...
# Ranked passages for batch:
# Charles William Mumy Jr. ( ; born February 1, 1954
# ...
# Ranked passages for batch:
# Bagpuss is a British children's television series,
# ...
# Ranked passages for batch:
# Catatonia is a state of psychogenic motor immobili
# ...
# Ranked passages for batch:
# Christopher J Morris (born 15 June 1962) is an Eng
# ...
# Ranked passages for batch:
# Chad ( ; Arabic: تشاد‎ ‎ "Tshād "; French: "Tchad"
# ...
# Ranked passages for batch:
# Creutzfeldt–Jakob disease (CJD) is a universally f
# ...
# Ranked passages for batch:
# Conscription, or drafting, is the compulsory enlis
# ...
# Ranked passages for batch:
# The Claudine series consists of four early novels
# ...
# Ranked passages for batch:
# Cytology (from Greek κύτος , "kytos", "a hollow";
# ...
# Ranked passages for batch:
# Claudius ( ; Latin: "Tiberius Claudius Caesar Augu
# ...
# Ranked passages for batch:
# Charles Baxter (born May 13, 1947) is an American
# ...
# Ranked passages for batch:
# Cretinism is a condition of severely stunted physi
# ...
# Ranked passages for batch:
# Children of Dune is a 1976 science fiction novel b
# ...
# Ranked passages for batch:
# The Cottingley Fairies appear in a series of five
# ...
# Ranked passages for batch:
# Denton True "Cy" Young (March 29, 1867 – November
# ...
# Ranked passages for batch:
# Chagas disease, also known as American trypanosomi
# ...
# Ranked passages for batch:
# Christopher "Chris" Sarandon, Jr. ( ; born July 24
# ...
# Ranked passages for batch:
# The Canchim breed is a breed of beef cattle develo
# ...
# Ranked passages for batch:
# Clive Stuart Anderson (born 10 December 1952 in St
# ...
# Ranked passages for batch:
# Calista Kay Flockhart (born November 11, 1964) is
# ...
# Ranked passages for batch:
# Clairvoyance (/klɛɹˈvɔɪəns/ or /klɛəˈvɔɪəns/) (fro
# ...
# Ranked passages for batch:
# The Civilian Conservation Corps (CCC) was a public
# ...
# Ranked passages for batch:
# The Kennedy family is an American political family
# ...
# Ranked passages for batch:
# Dino Zoff (] ; born 28 February 1942) is a former
# ...
# Ranked passages for batch:
# Domenico Alberti (c. 1710 – 14 October 1740) was a
# ...
# Ranked passages for batch:
# Down syndrome (DS or DNS), also known as trisomy 2
# ...
# Ranked passages for batch:
# Diagnostic and Statistical Manual of Mental Disord
# ...
# Ranked passages for batch:
# Donald Henry "Don" Rumsfeld (born July 9, 1932) is
# ...
# Ranked passages for batch:
# Dylan Marlais Thomas (27 October 1914 – 9 November
# ...
# Ranked passages for batch:
# Denis Colin Leary (born August 18, 1957) is an Ame
# ...
# Ranked passages for batch:
# Developmental psychology is the scientific study o
# ...
# Ranked passages for batch:
# Elvis Aaron Presley (January 8, 1935 – August 16,
# ...
# Ranked passages for batch:
# Endocrinology (from Greek ἔνδον , "endon", "within
# ...
# Ranked passages for batch:
# Eithne Pádraigín Ní Bhraonáin (anglicised as Enya
# ...
# Ranked passages for batch:
# Edgar Allan Poe ( ; born Edgar Poe; January 19, 18
# ...
# Ranked passages for batch:
# Elwyn Brooks "E. B." White (July 11, 1899 – Octobe
# ...
# Ranked passages for batch:
# Évariste Galois (] ; 25 October 1811 – 31 May 1832
# ...
# Ranked passages for batch:
# The following outline is provided as an overview o
# ...
# Ranked passages for batch:
# Elizabeth Ward Gracen (born Elizabeth Grace Ward,
# ...
# Ranked passages for batch:
# Embryo drawing is the illustration of embryos in t
# ...
# Ranked passages for batch:
# Educational psychology is the branch of psychology
# ...
# Ranked passages for batch:
# Eve Arden (April 30, 1908 – November 12, 1990) was
# ...
# Ranked passages for batch:
# Essential tremor (ET, also referred to as benign t
# ...
# Ranked passages for batch:
# The Finnish Defence Forces (Finnish: "Puolustusvoi
# ...
# Ranked passages for batch:
# The Fields Medal is a prize awarded to two, three,
# ...
# Ranked passages for batch:
# February 21 is the day of the year in the Gregoria
# ...
# Ranked passages for batch:
# February 17 is the day of the year in the Gregoria
# ...
# Ranked passages for batch:
# Flambards is a novel for children or young adults
# ...
# Ranked passages for batch:
# Friends (stylized as F•R•I•E•N•D•S) is an American
# ...
# Ranked passages for batch:
# Frederick Aaron "Fred" Savage (born July 9, 1976)
# ...
# Ranked passages for batch:
# Frederick Phillips "Fred" Brooks Jr. (born April 1
# ...
# Ranked passages for batch:
# George Walton Lucas Jr. (born May 14, 1944) is an
# ...
# Ranked passages for batch:
# The Demographics of Gabon is the makeup of the pop
# ...
# Ranked passages for batch:
# Guglielmo Marconi, 1st Marquis of Marconi ( ; ] ;
# ...
# Ranked passages for batch:
# Gary Wayne Coleman (February 8, 1968 – May 28, 201
# ...
# Ranked passages for batch:
# Goran Bregović (Serbian Cyrillic: , ] , born 22 Ma
# ...
# Ranked passages for batch:
# George Peppard Jr. ( ; October 1, 1928 – May 8, 19
# ...
# Ranked passages for batch:
# Garnet Edward "Ace" Bailey (June 13, 1948 – Septem
# ...
# Ranked passages for batch:
# Greg Egan (born 20 August 1961) is an Australian s
# ...
# Ranked passages for batch:
# George Robert Aberigh-Mackay (25 July 184812 Janua
# ...
# Ranked passages for batch:
# George Benson (born March 22, 1943) is an American
# ...
# Ranked passages for batch:
# James Gordon Brown (born 20 February 1951) is a fo
# ...
# Ranked passages for batch:
# Harold and Maude is a 1971 American romantic black
# ...
# Ranked passages for batch:
# Hans Gerhard Creutzfeldt (June 2, 1885 – December
# ...
# Ranked passages for batch:
# Homeschooling, also known as home education, is th
# ...
# Ranked passages for batch:
# Henri Chopin (18 June 1922 – 3 January 2008) was a
# ...
# Ranked passages for batch:
# Harold Edward Holt, {'1': ", '2': ", '3': ", '4':
# ...
# Ranked passages for batch:
# Females typically have a special ovipositor for in
# ...
# Ranked passages for batch:
# Infante D. Henrique of Portugal, Duke of Viseu (4
# ...
# Ranked passages for batch:
# The human immunodeficiency virus (HIV) is a lentiv
# ...
# Ranked passages for batch:
# Harry Julius Shearer (born December 23, 1943) is a
# ...
# Ranked passages for batch:
# Izabella Scorupco (born Izabela Dorota Skorupko, J
# ...
# Ranked passages for batch:
# The Iron Age is an archaeological era, referring t
# ...
# Ranked passages for batch:
# Erectile dysfunction (ED), also known as impotence
# ...
# Ranked passages for batch:
# An intelligence quotient (IQ) is a total score der
# ...
# Ranked passages for batch:
# An instructional theory is "a theory that offers e
# ...
# Ranked passages for batch:
# According to the biblical Book of Genesis, Isaac (
# ...
# Ranked passages for batch:
# Interstitial cystitis (IC), also known as bladder
# ...
# Ranked passages for batch:
# Infanticide (or infant homicide) is the intentiona
# ...
# Ranked passages for batch:
# Joshua Browning Carter Jackson (born June 11, 1978
# ...
# Ranked passages for batch:
# June 18 is the day of the year in the Gregorian ca
# ...
# Ranked passages for batch:
# Judit Polgár (born 23 July 1976) is a Hungarian ch
# ...
# Ranked passages for batch:
# Jonathan Michael Richman (born May 16, 1951) is an
# ...
# Ranked passages for batch:
# James Todd Spader (born February 7, 1960) is an Am
# ...
# Ranked passages for batch:
# John Martyn, OBE (11 September 1948 – 29 January 2
# ...
# Ranked passages for batch:
# Jacob Abbott (November 14, 1803 – October 31, 1879
# ...
# Ranked passages for batch:
# Judy Blume (born Judith Sussman; February 12, 1938
# ...
# Ranked passages for batch:
# Arturo Molina, Jr. (born May 31, 1964), better kno
# ...
# Ranked passages for batch:
# Kyle Merritt MacLachlan ( ; born February 22, 1959
# ...
# Ranked passages for batch:
# Kevin Norwood Bacon (born July 8, 1958) is an Amer
# ...
# Ranked passages for batch:
# Kenneth Mathieson Dalglish, MBE (born 4 March 1951
# ...
# Ranked passages for batch:
# Kay Redfield Jamison (born June 22, 1946) is an Am
# ...
# Ranked passages for batch:
# Kristine Tsuya Yamaguchi (born July 12, 1971) is a
# ...
# Ranked passages for batch:
# Katina Paxinou (; born Aikaterini Konstantopoulou
# ...
# Ranked passages for batch:
# The Kocher–Debré–Semelaigne syndrome is hypothyroi
# ...
# Ranked passages for batch:
# Lars Magnus Ericsson (5 May 1846 – 17 December 192
# ...
# Ranked passages for batch:
# Lebanon ( ; Arabic: لبنان‎ ‎ "Lubnān" ; ] ; French
# ...
# Ranked passages for batch:
# Lafora disease, also called Lafora progressive myo
# ...
# Ranked passages for batch:
# Louise Erdrich (born Karen Louise Erdrich, June 7,
# ...
# Ranked passages for batch:
# Lilia Oleksandrivna Podkopayeva (Ukrainian: Лілія
# ...
# Ranked passages for batch:
# Lev Vladimirovich Kuleshov (Russian: Лев Влади́мир
# ...
# Ranked passages for batch:
# Lyonel Charles Feininger (July 17, 1871January 13,
# ...
# Ranked passages for batch:
# Louis IX (25 April 1214 – 25 August 1270), commonl
# ...
# Ranked passages for batch:
# Language acquisition is the process by which human
# ...
# Ranked passages for batch:
# Matthew Abraham "Matt" Groening ( ; born February
# ...
# Ranked passages for batch:
# Myasthenia gravis (MG) is a long-term neuromuscula
# ...
# Ranked passages for batch:
# Martina Hingis (born 30 September 1980) is a Swiss
# ...
# Ranked passages for batch:
# Maya Ying Lin (born October 5, 1959) is an America
# ...
# Ranked passages for batch:
# Marilyn Monroe (born Norma Jeane Mortenson; June 1
# ...
# Ranked passages for batch:
# May 18 is the day of the year in the Gregorian cal
# ...
# Ranked passages for batch:
# May 17 is the day of the year in the Gregorian cal
# ...
# Ranked passages for batch:
# Maximilian Raoul Steiner (May 10, 1888 – December
# ...
# Ranked passages for batch:
# Michael Mackintosh Foot {'1': ", '2': ", '3': ", '
# ...
# Ranked passages for batch:
# Monica Samille Lewinsky (born July 23, 1973) is an
# ...
# Ranked passages for batch:
# Martin Luther King Jr. (born Michael King Jr., Jan
# ...
# Ranked passages for batch:
# Martin Fowler (born 1963) is a British software de
# ...
# Ranked passages for batch:
# March 21 is the day of the year in the Gregorian c
# ...
# Ranked passages for batch:
# Meconium aspiration syndrome (MAS) also known as n
# ...
# Ranked passages for batch:
# Morgan Freeman (born June 1, 1937) is an American
# ...
# Ranked passages for batch:
# Margaret Higgins Sanger (born Margaret Louise Higg
# ...
# Ranked passages for batch:
# Metamorphosis is a biological process by which an
# ...
# Ranked passages for batch:
# Robert Michael Nesmith (born December 30, 1942) is
# ...
# Ranked passages for batch:
# The Neolithic Age, Era, or Period, or New Stone Ag
# ...
# Ranked passages for batch:
# In the 2011 census, Nepal's population was approxi
# ...
# Ranked passages for batch:
# Tensions only get worse between Patterson and Seve
# ...
# Ranked passages for batch:
# Brown was elected to the Barrie City Council in 20
# ...
# Ranked passages for batch:
# In the Third Age, CÃ­rdan, recognizing Gandalf's t
# ...
# Ranked passages for batch:
# Most episodes feature a storyline taking place in
# ...
# Ranked passages for batch:
# A related concept in political science is the deve
# ...
# Ranked passages for batch:
# David McNally argues that the logic of the market
# ...
# Ranked passages for batch:
# 10" single
# ...
# Ranked passages for batch:
# Lloyd's philanthropist mother, Ruth Lapham Lloyd,
# ...
# Ranked passages for batch:
# A majority of people do not start smoking at adult
# ...
# Ranked passages for batch:
# In the Philippines, tobacco advertising is still a
# ...
# Ranked passages for batch:
# Several exemptions from this legislation remain:
# ...
# Ranked passages for batch:
# A 1994 report by the Surgeon General, "Preventing
# ...
# Ranked passages for batch:
# In 2008, during a non-NASCAR sanctioned series, wh
# ...
# Ranked passages for batch:
# According to census data, the child sex ratio (0â€
# ...
# Ranked passages for batch:
# The 509th Composite Group was constituted on Decem
# ...
# Ranked passages for batch:
# That day, Truman noted in his diary that:
# ...
# Ranked passages for batch:
# At 08:09, Tibbets started his bomb run and handed
# ...
# Ranked passages for batch:
# At 03:49 on the morning of August 9, 1945, Bocksca
# ...
# Ranked passages for batch:
# Despite the small sample size of 1600 to 1800 pers
# ...
# Ranked passages for batch:
# However either side of this radiosensitive age, no
# ...
# Ranked passages for batch:
# Wake is located two-thirds of the way between Hono
# ...
# Ranked passages for batch:
# On September 4, 1945, the Japanese garrison surren
# ...
# Ranked passages for batch:
# On March 12, 1986, the civil administrator of Wake
# ...
# Ranked passages for batch:
# The 611th Air Support Group (ASG), a U.S. Air Forc
# ...
# Ranked passages for batch:
# Two-party systems can be contrasted with:
# ...
# Ranked passages for batch:
# Sperm is the male reproductive cell and is derived
# ...
# Ranked passages for batch:
# Sperm is the male reproductive cell and is derived
# ...
# Ranked passages for batch:
# independent of the location of P.[13]
# ...
# Ranked passages for batch:
# which is the optic equation.
# ...
# Ranked passages for batch:
# The sine of 60Â° is
#
#
#
#
#
#
#
# 3
#
# 2
#
#
#
#
#
# {\displaysty
# ...
# Ranked passages for batch:
# "Crossing the Bar" is an 1889 poem by Alfred, Lord
# ...
# Ranked passages for batch:
# The arrangement has reappeared in other African co
# ...
# Ranked passages for batch:
# â€”Mark Foster[8]
# ...
# Ranked passages for batch:
# Protectionism is the economic policy of restrictin
# ...
# Ranked passages for batch:
# Protectionists postulate that new industries may r
# ...
# Ranked passages for batch:
# The budget for development of the stadium is estim
# ...
# Ranked passages for batch:
# A young Charlie Roan and her family are tied up by
# ...
# Ranked passages for batch:
# Originally, the film was set to be released on Mon
# ...
# Ranked passages for batch:
# In addition, there are several smaller bands:[37]
# ...
# Ranked passages for batch:
# A boy identified not only with his father but with
# ...
# Ranked passages for batch:
# Girls learned to gather healthy berries, nuts, and
# ...
# Ranked passages for batch:
# Bulls become fertile at about seven months of age.
# ...
# Ranked passages for batch:
# Bulls have held a place of significance in human c
# ...
# Ranked passages for batch:
# Environment – Current Issues:
# ...
# Ranked passages for batch:
# The Duanwu Festival, also often known, especially
# ...
# Ranked passages for batch:
#
# ...
# Ranked passages for batch:
# In August 1996, Kristen is hospitalized after an e
# ...
# Ranked passages for batch:
# Heating element heats the contents to a steady tem
# ...
# Ranked passages for batch:
# The RSPB has two separate groups for children and
# ...
# Ranked passages for batch:
# Upon learning that she is too young to start her o
# ...
# Ranked passages for batch:
# Juliet and Vanessa Skype Jenny, asking for help to
# ...
# Ranked passages for batch:
# The economy of the Hellenistic world, however, con
# ...
# Ranked passages for batch:
# The second King was a street urchin who was brough
# ...
# Ranked passages for batch:
# “Don’t Let Me Down” received critical acclaim. Rob
# ...
# Ranked passages for batch:
# Morrison died in his home at the age of 90 on Febr
# ...
# Ranked passages for batch:
# Provincial and territorial executive councils
# ...
# Ranked passages for batch:
# The film was first released onto DVD by Warner Hom
# ...
# Ranked passages for batch:
# When Tara and Willow meet, their proficiency at ma
# ...
# Ranked passages for batch:
# For boys, the uniforms generally include a button-
# ...
# Ranked passages for batch:
# Most schools pay attention to the shoes that can b
# ...
# Ranked passages for batch:
# Nowadays, many pre-schools advise parents to dress
# ...
# Ranked passages for batch:
# When children have P.E, they wear a polo or a shir
# ...
# Ranked passages for batch:
# Primary schoolï¼šWhite short pants and shirts are
# ...
# Ranked passages for batch:
# The Elementary Education Act 1870 introduced free
# ...
# Ranked passages for batch:
# The most common secondary school uniform in Northe
# ...
# Ranked passages for batch:
# School uniforms are used in Venezuela.[84] By Vene
# ...
# Ranked passages for batch:
# The story of the birth of Aeneas is told in the "H
# ...
# Ranked passages for batch:
# Production on the first season began in January 20
# ...
# Ranked passages for batch:
# The Selective Service Act of 1917 was carefully dr
# ...
# Ranked passages for batch:
# The World War I system served as a model for that
# ...
# Ranked passages for batch:
# On July 2, 1980, President Jimmy Carter issued Pre
# ...
# Ranked passages for batch:
# Some of the measures they have implemented include
# ...
# Ranked passages for batch:
# Names of some smaller territories:
# ...
# Ranked passages for batch:
# As a child, Christian Wolff is diagnosed with a hi
# ...
# Ranked passages for batch:
# Vince Mancini of Uproxx gave the film a positive r
# ...
# Ranked passages for batch:
# Another authorised sequel, The Best Bear in All th
# ...
# Ranked passages for batch:
# During the 1970s the BBC children's television sho
# ...
# Ranked passages for batch:
# According to the chemiosmotic coupling hypothesis,
# ...
# Ranked passages for batch:
# When bacteria grow in aerobic environments, the te
# ...
# Ranked passages for batch:
# Side A:
# ...
# Ranked passages for batch:
# A microscope slide is a thin flat piece of glass,
# ...
# Ranked passages for batch:
# Used when a permanent mount is required
# ...
# Ranked passages for batch:
# In order clockwise around the chamber:
# ...
# Ranked passages for batch:
# The United States Capitol Visitor Center (CVC), lo
# ...
# Ranked passages for batch:
# The second day of the Chinese New Year, known as "
# ...
# Ranked passages for batch:
# The seventh day, traditionally known as Renri (the
# ...
# Ranked passages for batch:
# "Happy New Year!" (Chinese: 新年好呀; pinyin: Xīn Nián
# ...
# Ranked passages for batch:
# Oddly and funny, most Chinese-Indonesian who are n
# ...
# Ranked passages for batch:
# Children and teenagers sometimes jokingly use the
# ...
# Ranked passages for batch:
# 21 August 1888: Completion of the second level.
# ...
# Ranked passages for batch:
# The Eiffel Tower sways by up to 9 centimetres (3.5
# ...
# Ranked passages for batch:
# Feisty 14 year-old farm girl Mattie Ross (Steinfel
# ...
# Ranked passages for batch:
# Open casting sessions were held in Texas in Novemb
# ...
# Ranked passages for batch:
# The film was released on DVD and Blu-ray on June 7
# ...
# Ranked passages for batch:
# In May 2017, a stabbing on campus near Gregory Gym
# ...
# Ranked passages for batch:
# In 2010, UT Austin opened the $100 million Dell Pe
# ...
# Ranked passages for batch:
# Several musicians and entertainers attended the un
# ...
# Ranked passages for batch:
# In its first weekend of limited release, the film
# ...
# Ranked passages for batch:
# With the exception of Benedict Samuel and Michael
# ...
# Ranked passages for batch:
# The civil rights of none shall be abridged on acco
# ...
# Ranked passages for batch:
# In Yates v. United States (1957), the Supreme Cour
# ...
# Ranked passages for batch:
# The Supreme Court has determined that the First Am
# ...
# Ranked passages for batch:
# Note that "community" standards—not national stand
# ...
# Ranked passages for batch:
# According to backup singer Regina Havis Brown, ori
# ...
# Ranked passages for batch:
# Some examples:
# ...
# Ranked passages for batch:
# Some examples:
# ...
# Ranked passages for batch:
# Thespis is a 2014 UK film, produced by ACT 2 CAM.
# ...
# Ranked passages for batch:
# While playing "Patience" at their October 11, 2017
# ...
# Ranked passages for batch:
# "I Wan'na Be like You" is a song from Walt Disney'
# ...
# Ranked passages for batch:
# Prince Sundjata was prophesied to become a great c
# ...
# Ranked passages for batch:
# A manuscript page from Timbuktu
# ...
# Ranked passages for batch:
# It is during the Kolonkan Keita lineage that the d
# ...
# Ranked passages for batch:
# Abu Abdallah Ibn Battuta was born in Morocco in th
# ...
# Ranked passages for batch:
# The original executive producer of the show, Geoff
# ...
# Ranked passages for batch:
# March 21, 2017
# ...
# Ranked passages for batch:
# In season one, surviving a car accident which kill
# ...
# Ranked passages for batch:
# Damon Salvatore (based on Damon Salvatore from the
# ...
# Ranked passages for batch:
# By season eight, Caroline is co-parenting her chil
# ...
# Ranked passages for batch:
# In season seven, it is revealed that the Gemini Co
# ...
# Ranked passages for batch:
# Anna developed romantic feelings for Jeremy, who s
# ...
# Ranked passages for batch:
# In season six, Liv continued attending college and
# ...
# Ranked passages for batch:
# The Articles of Confederation contain a preamble,
# ...
# Ranked passages for batch:
# The signers and the states they represented were:
# ...
# Ranked passages for batch:
# Article IX, ¶2 through ¶5
# ...
# Ranked passages for batch:
# Almora is located at 29°35′50″N 79°39′33″E﻿ / ﻿29.
# ...
# Ranked passages for batch:
# Municipal board (Nagar Palika Parishad) of Almora
# ...
# Ranked passages for batch:
# Division championships (20)
# ...
# Ranked passages for batch:
# In 1993, a new logo was unveiled involving the gra
# ...
# Ranked passages for batch:
# Strength and Conditioning
# ...
# Ranked passages for batch:
# The cable consisted of seven copper wires, each we
# ...
# Ranked passages for batch:
# Belle befriends the castle's servants, who invite
# ...
# Ranked passages for batch:
# It scored the biggest opening day of the year in H
# ...
# Ranked passages for batch:
# In Russia, Vitaly Milonov agitated the culture min
# ...
# Ranked passages for batch:
# They are large plants; the vines can be as long as
# ...
# Ranked passages for batch:
# As a relatively low-protein food, yam is not a goo
# ...
# Ranked passages for batch:
# In central parts of India, the yam (khamalu, suran
# ...
# Ranked passages for batch:
# The Rabbis, playing on the name Balaam, call him "
# ...
# Ranked passages for batch:
# Popular Indian singers include Lata Mangeshkar, Mo
# ...
# Ranked passages for batch:
# In the Roman Catholic Church, Ash Wednesday is obs
# ...
# Ranked passages for batch:
# In the mid-16th century, the first Book of Common
# ...
# Ranked passages for batch:
# The article on Ash Wednesday in the 1911 Encyclopæ
# ...
# Ranked passages for batch:
# Copper, although toxic in excessive amounts, is es
# ...
# Ranked passages for batch:
# "You'll Never Walk Alone" is a show tune from the
# ...
# Ranked passages for batch:
# The Deer Hunter is a 1978 American epic war drama
# ...
# Ranked passages for batch:
# Each of the six principal male characters carried
# ...
# Ranked passages for batch:
# Film critic and biographer David Thomson also agre
# ...
# Ranked passages for batch:
# In addition, the film was nominated in four other
# ...
# Ranked passages for batch:
# In humans, mature red blood cells are flexible and
# ...
# Ranked passages for batch:
# A typical human red blood cell has a disk diameter
# ...
# Ranked passages for batch:
# Human red blood cells are produced through a proce
# ...
# Ranked passages for batch:
# Special double-doubles are rare. One such double-d
# ...
# Ranked passages for batch:
# All facts based on data since 1985–86:
# ...
# Ranked passages for batch:
# Among the places that draw visitors are the former
# ...
# Ranked passages for batch:
# The Big Sur Folk Festival featured a lineup of eme
# ...
# Ranked passages for batch:
# Due to development restrictions and the limited nu
# ...
# Ranked passages for batch:
# In 1997, the Ventana Wildlife Society began releas
# ...
# Ranked passages for batch:
# My super fund and I would say many other funds giv
# ...
# Ranked passages for batch:
# Hmmmm, 1 or 2, yeah, maybe they were not a good fi
# ...
# Ranked passages for batch:
# "&gt; What kind of bullshit is this?     &gt;&gt;
# ...
# Ranked passages for batch:
# We're not talking about what's good for the parent
# ...
# Ranked passages for batch:
# Компанията предлага най-добрите ИТ продукти. Ние д
# ...
# Ranked passages for batch:
# "(relix already hit on some of this)  It's hard to
# ...
# Ranked passages for batch:
# I know exactly what you are talking about. You may
# ...
# Ranked passages for batch:
# "Yeah, so where are the scholarly articles? I don'
# ...
# Ranked passages for batch:
# "Although banks do not have to honor checks that a
# ...
# Ranked passages for batch:
# Depending on the state this might not be possible.
# ...
# Ranked passages for batch:
# I have had more than 1 co-worker tell me that they
# ...
# Ranked passages for batch:
#
# ...
# Ranked passages for batch:
# "First of all, never is too late to develop good h
# ...
# Ranked passages for batch:
# "The key point to answer the question is to consid
# ...
# Ranked passages for batch:
# "BINGO.  Only thing wrong in your statement is tha
# ...
# Ranked passages for batch:
# As a 22 year old planning for your financial life,
# ...
# Ranked passages for batch:
# Look at the left column.  If you are disabled at a
# ...
# Ranked passages for batch:
#
# ...
# Ranked passages for batch:
# "First thing I'd say is don't start with investing
# ...
# Ranked passages for batch:
# Less than 1/5th of the country. Narrowing down the
# ...
# Ranked passages for batch:
#
# ...
# Ranked passages for batch:
# "Get fucked with that idiocy mate. You can cut the
# ...
# Ranked passages for batch:
# "House prices do not go up.  Land prices in countr
# ...
# Ranked passages for batch:
# Here's the issue with LTC and, really, underwritte
# ...
# Ranked passages for batch:
# "As cars age, the amount of deprecation tends to d
# ...
# Ranked passages for batch:
# "**Noblesse oblige**  Noblesse oblige is a French
# ...
# Ranked passages for batch:
# "This is a funny article.  This kid is riding arou
# ...
# Ranked passages for batch:
# As a parent with a 4 yr old, it's not my reason. I
# ...
# Ranked passages for batch:
# This is a letter by a mother two her loving twin d
# ...
# Ranked passages for batch:
# "Thanks for the great response.  The example with
# ...
# Ranked passages for batch:
# A couple of thoughts from someone who's kind of be
# ...
# Ranked passages for batch:
# "Thanks for sharing.  I think it's a great idea to
# ...
# Ranked passages for batch:
# I would suggest equity research, or as mentioned,
# ...
# Ranked passages for batch:
# So if my father signed up for the military at age
# ...
# Ranked passages for batch:
# You're going to have a huge problem getting approv
# ...
# Ranked passages for batch:
# I don't see kids that are just post-college as fee
# ...
# Ranked passages for batch:
# Yeah, but your professional programs are insanely
# ...
# Ranked passages for batch:
# Если вы знаете сумму месячного розничного торговог
# ...
# Ranked passages for batch:
# "First, on Applebees:  &gt;Applebee’s is also asse
# ...
# Ranked passages for batch:
# "This is the best tl;dr I could make, [original](h
# ...
# Ranked passages for batch:
# That makes sense, no doubt there are a few market
# ...
# Ranked passages for batch:
# I'd suggest you put only 20% down if you qualify f
# ...
# Ranked passages for batch:
# **Stanford marshmallow experiment**  The Stanford
# ...
# Ranked passages for batch:
# $70k (plus 5-10% annual bonuses and medical/dental
# ...
# Ranked passages for batch:
# A trust is a financial arrangement to put aside mo
# ...
# Ranked passages for batch:
# The Child Care Expense Deduction (line 214) dollar
# ...
# Ranked passages for batch:
# In regards to the legal recourse, no there is none
# ...
# Ranked passages for batch:
#
# ...
# Ranked passages for batch:
# As someone with 6 kids, I just found out that I lo
# ...
# Ranked passages for batch:
# Child care - will a parent stay home? Bring Child
# ...
# Ranked passages for batch:
# &gt;Approximately 4.6 American adults will turn 65
# ...
# Ranked passages for batch:
# "More costs are going to be put on the consumer. B
# ...
# Ranked passages for batch:
# "There are two issues here: arithmetic and psychol
# ...
# Ranked passages for batch:
# "Your comment to James is telling and can help us
# ...
# Ranked passages for batch:
# "&gt;""Also, the social network is testing ways to
# ...
# Ranked passages for batch:
# "&gt; And moreover there is no way that Sculley wo
# ...
# Ranked passages for batch:
# Thank you. I try to lead my firm in a way where ev
# ...
# Ranked passages for batch:
# "This is the best tl;dr I could make, [original](h
# ...
# Ranked passages for batch:
#
# ...
# Ranked passages for batch:
# "I'm all for thrift stores and yard sales. When th
# ...
# Ranked passages for batch:
# AmeriKick Martial Arts show your best self preserv
# ...
# Ranked passages for batch:
# Two points.
# ...
# Ranked passages for batch:
# "Indeed. But it's worse than that. We now know tha
# ...
# Ranked passages for batch:
# The answer in theory is yes. The answer in reality
# ...
# Ranked passages for batch:
# 2.5 months. Male, 200 lbs., 5'10. over 10,000 step
# ...
# Ranked passages for batch:
# You are kicking butt and taking names, especially
# ...
# Ranked passages for batch:
# "&gt;The rules are regulations are setup as needed
# ...
# Ranked passages for batch:
# Your credit score is really bad, and it's highly u
# ...
# Ranked passages for batch:
# The long term view you are referring to would be o
# ...
# Ranked passages for batch:
# "This is a very uninformed statement. Becoming an
# ...
# Ranked passages for batch:
# "401k plans are required to not discriminate again
# ...
# Ranked passages for batch:
# First off, the basics on HST/GST:   You don't need
# ...
# Ranked passages for batch:
# "You said all terrorists are Muslims, which is not
# ...
# Ranked passages for batch:
# See Paying for Care | Caregiver Center | Alzheimer
# ...
# Ranked passages for batch:
# Let's say I am able to pass the level 1 CFA exam,
# ...
# Ranked passages for batch:
# "Well, perhaps ""have a dedicated tax advisor"" is
# ...
# Ranked passages for batch:
# "I think you just sum up the program,....""TONS of
# ...
# Ranked passages for batch:
# Lets say that college costs 100K per kid and they
# ...
# Ranked passages for batch:
# Because large stores do not pay their cashiers eno
# ...
# Ranked passages for batch:
# "Here's a sneak peek of /r/gatekeeping using the [
# ...
# Ranked passages for batch:
# Your gut feeling is absolutely spot on - you shoul
# ...
# Ranked passages for batch:
# "US federal tax law distinguishes many types of in
# ...
# Ranked passages for batch:
# "I'm a manager of a charity shop so work with a wi
# ...
# Ranked passages for batch:
# Every guess you made is incorrect I'm living fairl
# ...
# Ranked passages for batch:
# "For the person being hired this is a tricky situa
# ...
# Ranked passages for batch:
# The stock market at large has about a 4.5% long-te
# ...
# Ranked passages for batch:
# "According to the IRS, it appears there is no issu
# ...
# Ranked passages for batch:
# "**Yup!**  It's important to note that modern soft
# ...
# Ranked passages for batch:
# "Gotta beat them with price and games. You toss xb
# ...
# Ranked passages for batch:
# "Welcome to Personal Finance and Money. This answe
# ...
# Ranked passages for batch:
# I've never taken my 8 year old there, (he has been
# ...
# Ranked passages for batch:
# Who depends on you?   I personally wasn't insured
# ...
# Ranked passages for batch:
# It's great that you have gotten the itch to learn
# ...
# Ranked passages for batch:
# First, let me fill in the gaps on your situation,
# ...
# Ranked passages for batch:
# The check is just barely over 6 months old. I susp
# ...
# Ranked passages for batch:
# "#####&amp;#009;  ######&amp;#009;  ####&amp;#009;
# ...
# Ranked passages for batch:
# "Nobel laureate economist, Paul Krugman, wrote a p
# ...
# Ranked passages for batch:
# I have this problem with my parents.  They have st
# ...
# Ranked passages for batch:
# "Note - this is a complicated topic. I've read the
# ...
# Ranked passages for batch:
# A UTMA may or may not fit your situation. The main
# ...
# Ranked passages for batch:
# Intuitive? I doubt it. Derivatives are not the sim
# ...
# Ranked passages for batch:
# "I will answer the question from the back: who can
# ...
# Ranked passages for batch:
# http://www.wuug.org/read.php?13,11584 http://www.w
# ...
# Ranked passages for batch:
# The fluctuation of interest rates during the next
# ...
# Ranked passages for batch:
# The downsides:
# ...
# Ranked passages for batch:
# Excellent responses so far.  Because I am a math g
# ...
# Ranked passages for batch:
# Cryptocurrency is undoubtedly at the peak of Gartn
# ...
# Ranked passages for batch:
# "Boomers have also inordinately ""bid up"" the pri
# ...
# Ranked passages for batch:
# She seems to be paying an inordinate amount of mon
# ...
# Ranked passages for batch:
# First, before we talk about anything having to do
# ...
# Ranked passages for batch:
# "I don't ascribe your ""success"" to luck at all.
# ...
# Ranked passages for batch:
# For a long time, I thought that all the nice thing
# ...
# Ranked passages for batch:
# "&gt; President Trump killed the TPP? Yes, or no?
# ...
# Ranked passages for batch:
# Hello, My names Michael and I'm a 19 year old coll
# ...
# Ranked passages for batch:
# My credentials: I used to work on mortgages, about
# ...
# Ranked passages for batch:
# As AskAboutGadgets notes, there's no lower age lim
# ...
# Ranked passages for batch:
# "I never put race into it, but ok...  I hear lots
# ...
# Ranked passages for batch:
# If a parent has access to the birth certificate, s
# ...
# Ranked passages for batch:
# I am glad you agree that it makes much more sense
# ...
# Ranked passages for batch:
# "&gt; Why would he have had to have known about So
# ...
# Ranked passages for batch:
# "Give him a second chance to fix it.  Some compute
# ...
# Ranked passages for batch:
# "My dad keeps complaining that I treat him like a
# ...
# Ranked passages for batch:
# "&gt; So the fact that i was born here against my
# ...
# Ranked passages for batch:
# "Your question is very broad. Whole books can and
# ...
# Ranked passages for batch:
# "You have a few correlated questions here:  Yes yo
# ...
# Ranked passages for batch:
# "The answer is, there are a lot of answers! It alw
# ...
# Ranked passages for batch:
# "You're getting great wisdom and options. Establis
# ...
# Ranked passages for batch:
# Good, at least you are back to admitting that we h
# ...
# Ranked passages for batch:
# Conference on ‘Achieving Better Parenting for our
# ...
# Ranked passages for batch:
# My dad owned a steel Drum / barrel recycling compa
# ...
# Ranked passages for batch:
# "I work for 15 years now for the same company and
# ...
# Ranked passages for batch:
# "The only way to know the specific explanation in
# ...
# Ranked passages for batch:
# Two possibilities:
# ...
# Ranked passages for batch:
# "In California at least a little known secret is y
# ...
# Ranked passages for batch:
# "It is true that all else being equal, you will pa
# ...
# Ranked passages for batch:
# First of all, there are some differences between t
# ...
# Ranked passages for batch:
# "Now store the money in -- okay here, think about
# ...
# Ranked passages for batch:
# Welcome to newborn photography. We have many types
# ...
# Ranked passages for batch:
# Yes to all three. However,
# ...
# Ranked passages for batch:
# Last week, Barack Obama went to Osawatomie, Kansas
# ...
# Ranked passages for batch:
# That was a major statistic (that I can't find [Hon
# ...
# Ranked passages for batch:
# "I am surprised by the term ""spoil"". My kids wou
# ...
# Ranked passages for batch:
# Here are some ideas:
# ...
# Ranked passages for batch:
# There is no simple way to calculate how much house
# ...
# Ranked passages for batch:
# &gt; Cutting taxes to raise tax revenue is a fanta
# ...
# Ranked passages for batch:
# Yes, that's correct.
# ...
# Ranked passages for batch:
# "I'm assuming that by saying ""I'm a US resident n
# ...
# Ranked passages for batch:
# "But on June 28, the 17,000-resident town authoriz
# ...
# Ranked passages for batch:
# &gt; The only reason they didn't go bankrupt 20 ye
# ...
# Ranked passages for batch:
# "To the topic, and answering some of the questions
# ...
# Ranked passages for batch:
# An amortization schedule is often used to produce
# ...
# Ranked passages for batch:
# As a parent of under 13 year old kids, I think it
# ...
# Ranked passages for batch:
# "J Gruber's consulting reports for the various sta
# ...
# Ranked passages for batch:
# Interesting. The answer can be as convoluted/compl
# ...
# Ranked passages for batch:
# "&gt;All you have to do is survey the main cast of
# ...
# Ranked passages for batch:
# I'll be blunt.
# ...
# Ranked passages for batch:
# Will they still create programming catered to an 8
# ...

# %%
from sklearn.metrics import ndcg_score

def evaluate_retrieval(ranked_passages, relevance_scores, k=10):
    """
    Evaluate the ranked passages using NDCG (Normalized Discounted Cumulative Gain).
    
    Parameters:
    - ranked_passages: The indices of passages in the ranked order.
    - relevance_scores: A list of relevance scores for each passage (higher is more relevant).
    - k: Number of top passages to consider for NDCG calculation (default is 10).
    
    Returns:
    - ndcg: The NDCG score for the top-k ranked passages.
    """
    # Sort relevance_scores according to ranked_passages order
    ranked_relevance_scores = [relevance_scores[i] for i in ranked_passages]

    # Truncate to top k
    ranked_relevance_scores = ranked_relevance_scores[:k]
    relevance_scores = relevance_scores[:k]

    # Calculate NDCG score (expects a 2D array: [ground truth, predicted])
    ndcg = ndcg_score([relevance_scores], [ranked_relevance_scores], k=k)
    return ndcg

# Example usage
# Assuming you have ground truth relevance scores for each passage
relevance_scores = [3, 2, 1, 0, 0, 0]  # Example relevance scores for all passages
ranked_passages = [0, 2, 1, 4, 3]      # Indices of the ranked passages from your model

ndcg = evaluate_retrieval(ranked_passages, relevance_scores, k=5)
print(f"NDCG@5: {ndcg}")
# Out:
# NDCG@5: 0.9725044904464192
